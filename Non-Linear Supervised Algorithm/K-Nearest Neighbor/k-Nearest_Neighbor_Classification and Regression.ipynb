# %% [markdown]
# # K Nearest Neighborbours --> Classification and Regression

# %% [markdown]
# # Classification

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor

# %%
dataset = pd.read_csv("data.csv")
dataset.head()
# Out:
#    Age  Estimated Salary  Purchase
# 0   56             28392         0
# 1   46             50535         1
# 2   32             98603         0
# 3   25            133569         0
# 4   38             72256         0

# %%
sns.scatterplot(x="Age",y="Estimated Salary",data=dataset,hue="Purchase")
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["Purchase"]

# %%
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
x
# Out:
#          Age  Estimated Salary
# 0   1.487884         -1.607270
# 1   0.665394         -1.028861
# 2  -0.486092          0.226750
# 3  -1.061835          1.140116
# 4   0.007402         -0.461474
# ..       ...               ...
# 95  1.734631          0.937961
# 96  1.487884         -0.310048
# 97  1.652382         -1.252879
# 98  0.583145         -1.682030
# 99 -1.144084          0.651303
#
# [100 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_test,y_test)*100
# Out:
# 85.0

# %%
knn.score(x_train,y_train)*100
# Out:
# 87.5

# %%
knn.predict([[-1.144084	,0.651303]])
# Out:
# c:\Users\vikas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
for i in range(1,30):
    knn1 = KNeighborsClassifier(n_neighbors=i)
    knn1.fit(x_train,y_train)
    print(i,knn1.score(x_train,y_train)*100,knn1.score(x_test,y_test)*100)
# Out:
# 1 100.0 70.0
# 2 85.0 80.0
# 3 88.75 80.0
# 4 87.5 80.0
# 5 87.5 85.0
# 6 87.5 70.0
# 7 86.25 80.0
# 8 82.5 70.0
# 9 85.0 75.0
# 10 81.25 70.0
# 11 83.75 80.0
# 12 82.5 80.0
# 13 82.5 80.0
# 14 81.25 80.0
# 15 82.5 80.0
# 16 81.25 80.0
# 17 82.5 80.0
# 18 82.5 75.0
# 19 83.75 80.0
# 20 83.75 75.0
# 21 83.75 75.0
# 22 82.5 75.0
# 23 81.25 75.0
# 24 82.5 70.0
# 25 81.25 75.0
# 26 81.25 70.0
# 27 82.5 75.0
# 28 81.25 75.0
# 29 81.25 75.0

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=knn)
plt.show()
# Out:
# c:\Users\vikas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Regression

# %%
dataset = pd.read_csv("dataset.csv")

# %%
dataset.head()
# Out:
#    Age  Experience     Salary
# 0   59          38  101121.10
# 1   49          30   92061.10
# 2   35          14   52601.79
# 3   28           5   37261.86
# 4   41          20   59688.03

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
x = dataset.drop(columns="Salary")
y = dataset["Salary"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
knr = KNeighborsRegressor(n_neighbors=10)
knr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
knr.score(x_test,y_test)*100
# Out:
# 95.24638667233668

# %%
for i in range(1,30):
    knr1 = KNeighborsRegressor(n_neighbors=i)
    knr1.fit(x_train,y_train)
    print(i,knr1.score(x_train,y_train)*100,knr1.score(x_test,y_test)*100)
# Out:
# 1 93.81552441994911 91.68120431377527
# 2 95.6600371872609 93.93743946104752
# 3 96.01704330698547 93.95037446251628
# 4 96.06349983920181 94.11824237000533
# 5 96.13125063337718 94.5776716799674
# 6 96.12673938624324 94.77190416533196
# 7 96.12335392220278 94.85576458815336
# 8 96.04098899954835 94.85378073647972
# 9 96.02745180575357 95.19698276791792
# 10 96.04556449825216 95.24638667233668
# 11 95.99263876685255 95.31742876790467
# 12 95.9960878561363 95.422803029522
# 13 95.97661377406477 95.39367251235777
# 14 95.96916193381898 95.47775350771445
# 15 95.95255582476537 95.3463774429571
# 16 95.92306112440939 95.46479157536562
# 17 95.9100042940874 95.52864968958777
# 18 95.90684620379386 95.62119396339655
# 19 95.9137228665746 95.5632398850576
# 20 95.90261488066352 95.60360278527752
# 21 95.91860211996564 95.58757989216224
# 22 95.9186654509803 95.52320740731612
# 23 95.89364544594591 95.54063815131917
# 24 95.89491885286454 95.54819297807323
# 25 95.91696312890225 95.54592599120406
# 26 95.89691360001314 95.58539468183663
# 27 95.89581236605197 95.63339229879907
# 28 95.87926671622577 95.65898455476975
# 29 95.88738746930228 95.62357501189506

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv("polynomial_classification_dataset.csv")
dataset.head(3)
# Out:
#       data1     data2  output
# 0 -0.752759  1.188970       1
# 1  2.704286  0.216578       0
# 2  1.391964 -1.142834       1

# %%
sns.scatterplot(x='data1',y='data2',data=dataset,hue="output")
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["output"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
sv = SVC(kernel='rbf')

# %%
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
sv.score(x_test,y_test)*100
# Out:
# 92.75

# %%
sv.score(x_train,y_train)*100
# Out:
# 99.0

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=sv)
plt.show()
# Out:
# c:\Users\vikas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("Data_Set.csv")
dataset.head(3)
# Out:
#    Level  Salary
# 0      1   31335
# 1      2    4086
# 2      3   50884

# %%
plt.scatter(dataset["Level"],dataset["Salary"], color='green')
plt.xlabel("Level")
plt.ylabel("Salary")
plt.show()

# %%
dataset.corr()
# Out:
#            Level    Salary
# Level   1.000000  0.968466
# Salary  0.968466  1.000000

# %%
x = dataset[["Level"]]
y = dataset[["Salary"]]

# %%
from sklearn.preprocessing import PolynomialFeatures
pf = PolynomialFeatures(degree=2)
pf.fit(x)
x=pf.transform(x)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 99.99990025282987

# %%
plt.scatter(dataset["Level"],dataset["Salary"], color='green')
plt.plot(dataset["Level"], lr.predict(pf.transform(dataset[["Level"]])), color='red')
plt.xlabel("Level")
plt.legend(["Actual", "Predicted"])
plt.ylabel("Salary")
plt.show()

# %%
test = pf.transform([[31]])
test
# Out:
# c:\Users\Vikas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# array([[  1.,  31., 961.]])

# %%
lr.predict(test)
# Out:
# array([[1438986.00040152]])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("placement.csv")
dataset.head(3)
# Out:
#    cgpa  score  Placed
# 0  6.87     67       0
# 1  9.75     75       1
# 2  8.66     93       1

# %%
dataset.isnull().sum()
# Out:
# cgpa      0
# score     0
# Placed    0
# dtype: int64

# %%
sns.kdeplot(data=dataset("c"))

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa",y="score",data=dataset,hue="Placed")
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["Placed"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB , BernoulliNB

# %%
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
gnb.score(x_test,y_test)*100,gnb.score(x_test,y_test)*100
# Out:
# (100.0, 100.0)

# %%
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
mnb.score(x_train,y_train)*100,mnb.score(x_test,y_test)*100
# Out:
# (65.0, 90.0)

# %%
plt.figure(figsize=(4,3))
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=gnb)
plt.show()
# Out:
# c:\Users\Vikas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(4,3))
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=mnb)
plt.show()
# Out:
# c:\Users\Vikas\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
